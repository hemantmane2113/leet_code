# %%
def gcdOfStrings(str1: str, str2: str) -> str:

    n1 = len(str1)
    n2 = len(str2)

    #if n1 > n2:

    for i in range(1,n1+1):
        num_parts = i
        size = n1 // num_parts

        # List comprehension to slice and store parts
        parts_list = [str1[i : i + size] for i in range(0, n1, size)]
        #print(parts_list)

        for i in range(1,n2+1):
            all_match = all(item == str2[:i] for item in parts_list)
            #print(f"all_match for {str2[:i]}")

            if all_match == True:
                while n2:
                    n1,n2 = n2,(n1 % n2)

                return str1[:n1]

    return ''

# %%
str1 = "LEET"
str2 = "CODE"
bret = gcdOfStrings(str1, str2)
print(bret)

# %%
a = len("TAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXX")
b = len("TAUXXTAUXXTAUXXTAUXXTAUXX")

# %%
def gcd_iterative(a, b):
    while b:
        a, b = b, a % b
    return a

# %%
gcd_iterative(4,4)
# Out:
# 4

# %%
def gcdOfStrings(str1: str, str2: str) -> str:

    n1 = len(str1)
    n2 = len(str2)

    while n2:
        n1,n2 = n2,(n1 % n2)

    return n1

# %%
def gcdOfStrings(str1: str, str2: str) -> str:

    n1 = len(str1)
    n2 = len(str2)

    a = n1
    b = n2

    while b:
        a,b = b,(a % b)

    size = a

    candidate = str1[:size]


    if (candidate * (n1//size) == str1) and (candidate *(n2//size) == str2):
        return candidate
    else:
        return ""

# %%
str1 = "TAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXXTAUXX"
str2 = "TAUXXTAUXXTAUXXTAUXXTAUXX"
gcdOfStrings(str1, str2)
# Out:
# 'TAUXX'
