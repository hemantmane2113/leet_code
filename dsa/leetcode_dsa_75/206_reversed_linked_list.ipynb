# %%
from typing import Optional

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head or not head.next:
            return head

        previous = None
        current = head
        

        while current is not None:
            ahead = current.next
            current.next = previous
            previous = current
            current = ahead


        return previous

# %%
# 1.Helper function to turn a Python list into Linked List nodes
def make_linked_list(arr):
    if not arr: return None
    
    head = ListNode(arr[0])
    current = head
    for num in arr[1:]:
        current.next = ListNode(num)
        current = current.next
    return head

# %%
# 2.Helper function Convert Linked List back to Python list for easy printing
def print_linked_list(head):
    result = []
    current = head
    while current:
        result.append(str(current.val))
        current = current.next
    print(" -> ".join(result))

# %%
my_list = Solution()

# %%
head = make_linked_list([1, 2, 3, 4, 5])

# Pass the true linked list head to your function
iret = my_list.reverseList(head)
print_linked_list(iret) #
# Out:
# 5 -> 4 -> 3 -> 2 -> 1
