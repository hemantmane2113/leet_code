# %%
n = 537
ns = list(str(n))
print(ns)
# Out:
# ['5', '3', '7']

# %%
new_list = []
multiple = 1
print(ns)
for i in range(len(ns)-1,-1,-1):
    new_number = int(ns[i]) * multiple
    print
    new_list.append(new_number)
    multiple = multiple * 10
    new_list.sort(reverse = True)
print(new_list)
# Out:
# ['5', '3', '7']
# [500, 30, 7]

# %%
num = 102
digit_list = []
while num > 0:
    digit = num % 10
    digit_list.append(digit)
    num = num // 10
print(digit_list)
# Out:
# [2, 0, 1]

# %%
print(digit_list)
num_list = []
multiple = 1
for i in range(len(digit_list)):
    new_num = digit_list[i] * multiple
    num_list.append(new_num)
    multiple = multiple * 10
    print("num_list: ",num_list)
    num_list.sort(reverse = True)
    if 0 in num_list:
        num_list.remove(0)
    
print("num_list: ",num_list)
# Out:
# [2, 0, 1]
# num_list:  [2]
# num_list:  [2, 0]
# num_list:  [2, 100]
# num_list:  [100, 2]

# %%
# ❌ WRONG (Crashes)
l_list = final_list.sorted(reverse=True) 

#  RIGHT (Creates a new list)
l_list = sorted(final_list, reverse=True) 

#  RIGHT (Modifies the existing list)
final_list.sort(reverse=True)
